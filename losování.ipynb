# %%
from collections import Counter
from random import randrange

# %%
seznam_cisel = [randrange(16) for _ in range(1000)]

# %%
seznam_cisel
# Out:
# [10,
#  12,
#  1,
#  0,
#  15,
#  5,
#  2,
#  0,
#  10,
#  0,
#  8,
#  4,
#  11,
#  6,
#  2,
#  2,
#  14,
#  11,
#  9,
#  8,
#  10,
#  11,
#  4,
#  10,
#  10,
#  15,
#  13,
#  7,
#  12,
#  9,
#  9,
#  6,
#  9,
#  9,
#  5,
#  8,
#  14,
#  9,
#  12,
#  10,
#  9,
#  5,
#  4,
#  13,
#  12,
#  5,
#  3,
#  4,
#  2,
#  2,
#  9,
#  11,
#  3,
#  9,
#  4,
#  1,
#  3,
#  10,
#  0,
#  11,
#  13,
#  9,
#  5,
#  1,
#  5,
#  5,
#  3,
#  1,
#  12,
#  6,
#  4,
#  10,
#  2,
#  13,
#  14,
#  0,
#  10,
#  10,
#  0,
#  12,
#  15,
#  1,
#  13,
#  15,
#  11,
#  8,
#  0,
#  14,
#  1,
#  7,
#  9,
#  0,
#  15,
#  0,
#  9,
#  1,
#  9,
#  13,
#  6,
#  4,
#  6,
#  2,
#  3,
#  5,
#  14,
#  8,
#  8,
#  13,
#  11,
#  8,
#  15,
#  2,
#  12,
#  2,
#  2,
#  8,
#  13,
#  0,
#  9,
#  4,
#  9,
#  2,
#  4,
#  5,
#  4,
#  0,
#  8,
#  11,
#  2,
#  1,
#  14,
#  11,
#  14,
#  11,
#  9,
#  2,
#  0,
#  4,
#  15,
#  0,
#  4,
#  3,
#  7,
#  1,
#  6,
#  15,
#  0,
#  5,
#  10,
#  0,
#  3,
#  7,
#  2,
#  1,
#  0,
#  13,
#  0,
#  3,
# ...

# %%
c = Counter(seznam_cisel)

# %%
c
# Out:
# Counter({10: 75,
#          12: 69,
#          1: 61,
#          0: 68,
#          15: 68,
#          5: 71,
#          2: 63,
#          8: 54,
#          4: 60,
#          11: 56,
#          6: 49,
#          14: 60,
#          9: 74,
#          13: 60,
#          7: 48,
#          3: 64})

# %%
c.most_common(10)
# Out:
# [(10, 75),
#  (9, 74),
#  (5, 71),
#  (12, 69),
#  (0, 68),
#  (15, 68),
#  (3, 64),
#  (2, 63),
#  (1, 61),
#  (4, 60)]
